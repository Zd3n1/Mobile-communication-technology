# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/zdeni/Mendelu/Navazujici 3/Mobile communication technology/Mobile communication/NISQA results/NISQA_results.csv')

# %%
df
# Out:
#                   deg  mos_pred  noi_pred  dis_pred  col_pred  loud_pred  \
# 0  output-16-8khz.wav  3.071137  3.476582   3.87722  2.812172   3.192344
#
#      model
# 0  NISQAv2

# %%
mos_list = df['mos_pred'].to_list()

# %%
# %pip install mathplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement mathplotlib (from versions: none)
# ERROR: No matching distribution found for mathplotlib
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mathplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import mathplotlib as plt
#
# ModuleNotFoundError: No module named 'mathplotlib'

# %%
dataframes = [df, df_gsm]
mos_avg = []
mos_std = []
for data in dataframes:
    mos_avg.append(data['mos_pred'].mean())
    mos_std.append(data['mos_pred'].std())
